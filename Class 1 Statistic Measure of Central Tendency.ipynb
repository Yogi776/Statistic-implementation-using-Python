# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
url = 'https://gist.githubusercontent.com/curran/a08a1080b88344b0c8a7/raw/0e7a9b0a5d22642a06d3d5b9bcbad9890c8ee534/iris.csv'

# %%
data = pd.read_csv(url)

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
data.tail()
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica

# %%
data.size
# Out:
# 750

# %%
data.describe().T
# Out:
#               count      mean       std  min  25%   50%  75%  max
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9
# sepal_width   150.0  3.054000  0.433594  2.0  2.8  3.00  3.3  4.4
# petal_length  150.0  3.758667  1.764420  1.0  1.6  4.35  5.1  6.9
# petal_width   150.0  1.198667  0.763161  0.1  0.3  1.30  1.8  2.5

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 5 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   sepal_length  150 non-null    float64
#  1   sepal_width   150 non-null    float64
#  2   petal_length  150 non-null    float64
#  3   petal_width   150 non-null    float64
#  4   species       150 non-null    object
# dtypes: float64(4), object(1)
# memory usage: 6.0+ KB

# %%
sns.pairplot(data,hue='species')

# %%
data.columns
# Out:
# Index(['sepal_length', 'sepal_width', 'petal_length', 'petal_width',
#        'species'],
#       dtype='object')

# %% [markdown]
# # Mean of Data

# %%
data['sepal_length'].mean()
# Out:
# 5.843333333333335

# %%
data['sepal_width'].mean()
# Out:
# 3.0540000000000007

# %%
data['petal_length'].mean()
# Out:
# 3.7586666666666693

# %%
data['petal_width'].mean()
# Out:
# 1.1986666666666672

# %% [markdown]
# # Mode of Data

# %%
data['sepal_length'].mode()
# Out:
# 0    5.0
# dtype: float64

# %%
data['sepal_width'].mode()
# Out:
# 0    3.0
# dtype: float64

# %%
data['petal_length'].mode()
# Out:
# 0    1.5
# dtype: float64

# %%
data['petal_width'].mode()
# Out:
# 0    0.2
# dtype: float64

# %% [markdown]
# # Median of Data

# %%
data['sepal_length'].median()
# Out:
# 5.8

# %%
data['sepal_width'].median()
# Out:
# 3.0

# %%
data['petal_length'].median()
# Out:
# 4.35

# %%
data['petal_width'].median()
# Out:
# 1.3

# %% [markdown]
# ## Summary of mean, median and Mode of Data Set

# %%
print("Mean of sepal_length: ",data['sepal_length'].mean())
print("Mode of sepal_length:",data['sepal_length'].mode())
print("Median of sepal_length: ",data['sepal_length'].median())
# Out:
# Mean of sepal_length:  5.843333333333335
# Mode of sepal_length: 0    5.0
# dtype: float64
# Median of sepal_length:  5.8

# %%
print("Mean of sepal_width: ",data['sepal_width'].mean())
print("Mode of sepal_width:",data['sepal_width'].mode())
print("Median of sepal_width: ",data['sepal_width'].median())
# Out:
# Mean of sepal_width:  3.0540000000000007
# Mode of sepal_width: 0    3.0
# dtype: float64
# Median of sepal_width:  3.0

# %%
print("Mean of petal_length: ",data['petal_length'].mean())
print("Mode of petal_length:",data['petal_length'].mode())
print("Median of petal_length: ",data['petal_length'].median())
# Out:
# Mean of petal_length:  3.7586666666666693
# Mode of petal_length: 0    1.5
# dtype: float64
# Median of petal_length:  4.35

# %%
print("Mean of petal_width: ",data['petal_width'].mean())
print("Mode of petal_width:",data['petal_width'].mode())
print("Median of petal_width: ",data['petal_width'].median())
# Out:
# Mean of petal_width:  1.1986666666666672
# Mode of petal_width: 0    0.2
# dtype: float64
# Median of petal_width:  1.3

# %% [markdown]
# ## How to plot bell Curve shape in Python

# %%
data['species'].unique()
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype=object)

# %%
sns.distplot(data['sepal_length'])
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.distplot(data['sepal_length'],kde=False)
# Out:
# <AxesSubplot:xlabel='sepal_length'>

# %%
sns.distplot(data['sepal_length'],kde=True)
# Out:
# <AxesSubplot:xlabel='sepal_length', ylabel='Density'>

# %%
sns.pairplot(data,hue ='species',size=4)

# %% [markdown]
# ## Important Conculsion:-
#
# ### 1. Which one have least standard Deviation :- Blue
# ### 2. Which one have Higest Standard Deviation :- Green

# %%
sns.FacetGrid(data,hue='species',size=12).map(sns.distplot,'sepal_length').add_legend()

# %%
sns.FacetGrid(data,hue='species',size=12).map(sns.distplot,'sepal_width').add_legend()

# %%
sns.FacetGrid(data,hue='species',size=12).map(sns.distplot,'petal_length').add_legend()

# %%
sns.FacetGrid(data,hue='species',size=12).map(sns.distplot,'petal_width').add_legend()

# %% [markdown]
# ## How to convert Standard Deviation

# %%
print("Mean of sepal_length: ",data['sepal_length'])
print("Mean of sepal_width: ",data['sepal_width'])
print("Mean of petal_length: ",data['petal_length'])
print("Mean of petal_width: ",data['petal_width'])

# %%
print(np.std(data['sepal_length']))
print(np.std(data['sepal_width']))
print(np.std(data['petal_length']))
print(np.std(data['petal_width']))
# Out:
# 0.8253012917851409
# 0.4321465800705435
# 1.7585291834055201
# 0.760612618588172

# %%
data['sepal_length'] = np.std(data['sepal_length'])

# %%
data['sepal_width'] = np.std(data['sepal_width'])
data['petal_length'] = np.std(data['petal_length'])
data['petal_width'] = np.std(data['petal_width'])

# %%
sns.pairplot(data)

# %%
sns.pairplot(data,hue ='species')

# %%
sns.barplot(data=data)
# Out:
# <AxesSubplot:>
