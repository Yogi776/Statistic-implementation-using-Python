# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv('weight-height.csv')

# %%
data
# Out:
#       Gender     Height      Weight
# 0       Male  73.847017  241.893563
# 1       Male  68.781904  162.310473
# 2       Male  74.110105  212.740856
# 3       Male  71.730978  220.042470
# 4       Male  69.881796  206.349801
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [10000 rows x 3 columns]

# %%
data.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
data.tail()
# Out:
#       Gender     Height      Weight
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103

# %%
data.isnull().sum()
# Out:
# Gender    0
# Height    0
# Weight    0
# dtype: int64

# %%
data.describe().T
# Out:
#           count        mean        std        min         25%         50%  \
# Height  10000.0   66.367560   3.847528  54.263133   63.505620   66.318070
# Weight  10000.0  161.440357  32.108439  64.700127  135.818051  161.212928
#
#                75%         max
# Height   69.174262   78.998742
# Weight  187.169525  269.989699

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Gender  10000 non-null  object
#  1   Height  10000 non-null  float64
#  2   Weight  10000 non-null  float64
# dtypes: float64(2), object(1)
# memory usage: 234.5+ KB

# %%
data['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %% [markdown]
# ## Find Male and Female Separate from Data

# %%
data['Gender']=='Male'
# Out:
# 0        True
# 1        True
# 2        True
# 3        True
# 4        True
#         ...
# 9995    False
# 9996    False
# 9997    False
# 9998    False
# 9999    False
# Name: Gender, Length: 10000, dtype: bool

# %%
data[data['Gender']=='Male']
# Out:
#      Gender     Height      Weight
# 0      Male  73.847017  241.893563
# 1      Male  68.781904  162.310473
# 2      Male  74.110105  212.740856
# 3      Male  71.730978  220.042470
# 4      Male  69.881796  206.349801
# ...     ...        ...         ...
# 4995   Male  68.860062  177.131052
# 4996   Male  68.973423  159.285228
# 4997   Male  67.013795  199.195400
# 4998   Male  71.557718  185.905909
# 4999   Male  70.351880  198.903012
#
# [5000 rows x 3 columns]

# %%
data[data['Gender']=='Female']
# Out:
#       Gender     Height      Weight
# 5000  Female  58.910732  102.088326
# 5001  Female  65.230013  141.305823
# 5002  Female  63.369004  131.041403
# 5003  Female  64.479997  128.171511
# 5004  Female  61.793096  129.781407
# ...      ...        ...         ...
# 9995  Female  66.172652  136.777454
# 9996  Female  67.067155  170.867906
# 9997  Female  63.867992  128.475319
# 9998  Female  69.034243  163.852461
# 9999  Female  61.944246  113.649103
#
# [5000 rows x 3 columns]

# %%
data_male = data[data['Gender']=='Male']
data_female = data[data['Gender']=='Female']

# %%
data_male.head()
# Out:
#   Gender     Height      Weight
# 0   Male  73.847017  241.893563
# 1   Male  68.781904  162.310473
# 2   Male  74.110105  212.740856
# 3   Male  71.730978  220.042470
# 4   Male  69.881796  206.349801

# %%
data_female.head()
# Out:
#       Gender     Height      Weight
# 5000  Female  58.910732  102.088326
# 5001  Female  65.230013  141.305823
# 5002  Female  63.369004  131.041403
# 5003  Female  64.479997  128.171511
# 5004  Female  61.793096  129.781407

# %% [markdown]
# ## Univariate, Bivariate, Multivariate Analysis

# %% [markdown]
# ### 1. Ploting with 1 Dimension:- Univariate Analysis

# %%
plt.plot(data_male['Height'],np.zeros_like(data_male['Height']),'bo')
plt.plot(data_female['Height'],np.zeros_like(data_female['Height']),'ro')
plt.show()

# %% [markdown]
# ## Conclusion:-
#
# - 1 D  we can't conclude correct Analysis

# %% [markdown]
# ### 2. Ploting with 2 Dimension:- Bivariate Graph Analysis

# %%
sns.FacetGrid(data,hue = 'Gender',size = 8).map(sns.distplot,'Height').add_legend()

# %%
sns.FacetGrid(data,hue = 'Gender',size = 8).map(sns.distplot,'Weight').add_legend()

# %%
sns.distplot(data_male['Height'])
# Out:
# <AxesSubplot:xlabel='Height', ylabel='Density'>

# %%
sns.distplot(data_male['Height'],kde=False)
# Out:
# <AxesSubplot:xlabel='Height'>

# %% [markdown]
# # Percentile

# %% [markdown]
# ## What is use of Percentile in Data Science?

# %% [markdown]
# Suppose I am working E-Commerce Comapany,
#
# Taking delivery more than 5 days:-
#
#     In delivery 1 day, 2 days, 3 days, 4 days, 5 days .................. n days.
#
#     if I Find 5 days to we used percentile.

# %%
print('25 percent value is : ',np.percentile(data_male['Weight'],25))
print('50 percent value is : ',np.percentile(data_male['Weight'],50))
print('75 percent value is : ',np.percentile(data_male['Weight'],75))
print('90 percent value is : ',np.percentile(data_male['Weight'],90))
print('100 percent value is : ',np.percentile(data_male['Weight'],100))
# Out:
# 25 percent value is :  173.887767334218
# 50 percent value is :  187.033546088862
# 75 percent value is :  200.35780180200078
# 90 percent value is :  211.76868488615952
# 100 percent value is :  269.989698505106

# %% [markdown]
# # Cumulative Density Function

# %% [markdown]
# ## 1. What is pdf?
#
# ### Ans:-  Smoother version of histrogram
#
# #### Where Y axis is Probability Value

# %% [markdown]
# ## Example:-

# %%
#getting data from histrogram
count,bins_count = np.histogram(data_male['Weight'],bins=10)

#Finding pdf of the Histrogram using Count values
pdf = count / sum(count)

# using numpy np.cusum to calculate cdf 
cdf = np.cumsum(pdf)

#Ploting pdf and cdf

plt.plot(bins_count[1:],pdf,color = 'red',label = 'PDF')
plt.plot(bins_count[1:],cdf,label = 'CDF')
plt.show()

# %%
#getting data from histrogram
count,bins_count = np.histogram(data_male['Height'],bins=10)

#Finding pdf of the Histrogram using Count values
pdf = count / sum(count)

# using numpy np.cusum to calculate cdf 
cdf = np.cumsum(pdf)

#Ploting pdf and cdf

plt.plot(bins_count[1:],pdf,color = 'red',label = 'PDF')
plt.plot(bins_count[1:],cdf,label = 'CDF')
plt.show()

# %% [markdown]
# # Multivariate Analysis

# %%
plt.scatter(data['Weight'],data['Height'])
plt.xlabel('Weight',fontsize =13)
plt.ylabel('Height',fontsize = 13)
plt.show()

# %%
plt.hist(data['Weight'])
plt.show()

# %%
sns.pairplot(data,hue = 'Gender')

# %%
sns.jointplot(x = 'Weight',y='Height',data=data,kind = 'kde')
